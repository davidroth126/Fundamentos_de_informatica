# %%
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt 
import matplotlib.cm as cm 
import numpy as np
from scipy import stats

# %%
datos = pd.read_csv("https://raw.githubusercontent.com/AJVelezRueda/Fundamentos_de_informatica/master/Ciencia_de_datos/practicos/recursos/practico4.csv")
datos
# Out:
#          Fecha    Dirección IP  Actividad (en hs)  Acceso a Facebook (en hs)  \
# 0     16/09/20  242.99.117.120               3.36                       0.57
# 1     06/05/20    181174223110               4.28                       2.91
# 2     01/10/21   58.54.184.167               5.62                       2.60
# 3     01/03/17  135.79.184.226               5.83                       2.15
# 4     01/02/21    248.230.40.6               4.59                       1.79
# ...        ...             ...                ...                        ...
# 1000  02/04/20   93.205.225.51               5.68                       1.95
# 1001  07/02/19   43.55.114.100               4.62                       2.05
# 1002  25/01/20  147.210.83.222               6.21                       1.98
# 1003  03/07/17  117.69.141.168               4.69                       2.41
# 1004  09/03/18   29.229.177.12               6.50                       1.62
#
#       Acceso a Instagram (en hs)  Acceso a Twitch (en hs)  \
# 0                           8.81                     1.95
# 1                           9.66                     3.45
# 2                           6.95                     1.94
# 3                           7.82                     2.03
# 4                          11.67                     1.46
# ...                          ...                      ...
# 1000                        1.76                    10.00
# 1001                        2.53                     5.55
# 1002                        1.58                     8.84
# 1003                        1.70                     9.35
# 1004                        1.98                    14.53
#
#       Acceso a TikTok (en hs)
# 0                        3.69
# 1                        4.06
# 2                        4.77
# 3                        4.19
# 4                        5.39
# ...                       ...
# 1000                     8.40
# 1001                    10.96
# 1002                    14.01
# 1003                     8.83
# 1004                     4.46
#
# [1005 rows x 7 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Fecha                       1005 non-null   object
#  1   Dirección IP                1005 non-null   object
#  2   Actividad (en hs)           1005 non-null   float64
#  3   Acceso a Facebook (en hs)   1000 non-null   float64
#  4   Acceso a Instagram (en hs)  990 non-null    float64
#  5   Acceso a Twitch (en hs)     999 non-null    float64
#  6   Acceso a TikTok (en hs)     950 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 55.1+ KB

# %%
datos.describe()
# Out:
#        Actividad (en hs)  Acceso a Facebook (en hs)  \
# count        1005.000000                1000.000000
# mean            9.579622                   3.707200
# std             5.721012                   2.898833
# min            -2.060000                   0.570000
# 25%             4.810000                   2.027500
# 50%             8.030000                   2.860000
# 75%            14.000000                   5.032500
# max            34.450000                  37.060000
#
#        Acceso a Instagram (en hs)  Acceso a Twitch (en hs)  \
# count                  990.000000               999.000000
# mean                     5.946747                 5.158248
# std                      3.962645                 3.840922
# min                      0.450000                 0.010000
# 25%                      2.100000                 2.010000
# 50%                      6.385000                 3.660000
# 75%                      9.377500                 8.085000
# max                     22.960000                23.680000
#
#        Acceso a TikTok (en hs)
# count               950.000000
# mean                  4.189189
# std                   2.815012
# min                   0.060000
# 25%                   2.162500
# 50%                   3.605000
# 75%                   5.147500
# max                  19.230000

# %%
sns.heatmap(datos.isnull(),cmap="viridis")
# Out:
# <AxesSubplot:>

# %%
datos.dropna()
# Out:
#          Fecha    Dirección IP  Actividad (en hs)  Acceso a Facebook (en hs)  \
# 0     16/09/20  242.99.117.120               3.36                       0.57
# 1     06/05/20    181174223110               4.28                       2.91
# 2     01/10/21   58.54.184.167               5.62                       2.60
# 3     01/03/17  135.79.184.226               5.83                       2.15
# 4     01/02/21    248.230.40.6               4.59                       1.79
# ...        ...             ...                ...                        ...
# 1000  02/04/20   93.205.225.51               5.68                       1.95
# 1001  07/02/19   43.55.114.100               4.62                       2.05
# 1002  25/01/20  147.210.83.222               6.21                       1.98
# 1003  03/07/17  117.69.141.168               4.69                       2.41
# 1004  09/03/18   29.229.177.12               6.50                       1.62
#
#       Acceso a Instagram (en hs)  Acceso a Twitch (en hs)  \
# 0                           8.81                     1.95
# 1                           9.66                     3.45
# 2                           6.95                     1.94
# 3                           7.82                     2.03
# 4                          11.67                     1.46
# ...                          ...                      ...
# 1000                        1.76                    10.00
# 1001                        2.53                     5.55
# 1002                        1.58                     8.84
# 1003                        1.70                     9.35
# 1004                        1.98                    14.53
#
#       Acceso a TikTok (en hs)
# 0                        3.69
# 1                        4.06
# 2                        4.77
# 3                        4.19
# 4                        5.39
# ...                       ...
# 1000                     8.40
# 1001                    10.96
# 1002                    14.01
# 1003                     8.83
# 1004                     4.46
#
# [927 rows x 7 columns]

# %%
columnas = list(datos.columns)

# %%
columnas
# Out:
# ['Fecha',
#  'Dirección IP',
#  'Actividad (en hs)',
#  'Acceso a Facebook (en hs)',
#  'Acceso a Instagram (en hs)',
#  'Acceso a Twitch (en hs)',
#  'Acceso a TikTok (en hs)']

# %%
del(columnas[0:2])
columnas
# Out:
# ['Actividad (en hs)',
#  'Acceso a Facebook (en hs)',
#  'Acceso a Instagram (en hs)',
#  'Acceso a Twitch (en hs)',
#  'Acceso a TikTok (en hs)']

# %% [markdown]
# PAra saber si es normal o no

# %%
def verificacion_de_medias(lista):
    test = {}
    for columna in lista:
        w, p = stats.shapiro(datos[columna].dropna())
        test[columna] = p 
        return test

# %%
columnas
# Out:
# ['Actividad (en hs)',
#  'Acceso a Facebook (en hs)',
#  'Acceso a Instagram (en hs)',
#  'Acceso a Twitch (en hs)',
#  'Acceso a TikTok (en hs)']

# %%
verificacion_de_medias(columnas)
# Out:
# {'Actividad (en hs)': 6.711347348290036e-20}

# %%
sns.pairplot(datos)

# %%
datos.quantile(0.05).to_dict()
# Out:
# {'Actividad (en hs)': 2.68,
#  'Acceso a Facebook (en hs)': 1.38,
#  'Acceso a Instagram (en hs)': 1.4244999999999999,
#  'Acceso a Twitch (en hs)': 0.83,
#  'Acceso a TikTok (en hs)': 1.41}

# %% [markdown]
# PAra sacar outlayers

# %%
Cs1 = datos["Actividad (en hs)"].quantile(0.95)
Ci1 = datos["Actividad (en hs)"].quantile(0.05)
Cs2 = datos["Acceso a Instagram (en hs)"].quantile(0.95)
Ci2 = datos["Acceso a Instagram (en hs)"].quantile(0.05)

datos1= datos[(datos['Actividad (en hs)'] >= Ci1) & (datos['Actividad (en hs)'] <= Cs1) & (datos['Acceso a Instagram (en hs)'] >= Ci2) & (datos['Acceso a Instagram (en hs)'] <= Cs2)]

# %%
datos1
# Out:
#          Fecha    Dirección IP  Actividad (en hs)  Acceso a Facebook (en hs)  \
# 0     16/09/20  242.99.117.120               3.36                       0.57
# 1     06/05/20    181174223110               4.28                       2.91
# 2     01/10/21   58.54.184.167               5.62                       2.60
# 3     01/03/17  135.79.184.226               5.83                       2.15
# 4     01/02/21    248.230.40.6               4.59                       1.79
# ...        ...             ...                ...                        ...
# 1000  02/04/20   93.205.225.51               5.68                       1.95
# 1001  07/02/19   43.55.114.100               4.62                       2.05
# 1002  25/01/20  147.210.83.222               6.21                       1.98
# 1003  03/07/17  117.69.141.168               4.69                       2.41
# 1004  09/03/18   29.229.177.12               6.50                       1.62
#
#       Acceso a Instagram (en hs)  Acceso a Twitch (en hs)  \
# 0                           8.81                     1.95
# 1                           9.66                     3.45
# 2                           6.95                     1.94
# 3                           7.82                     2.03
# 4                          11.67                     1.46
# ...                          ...                      ...
# 1000                        1.76                    10.00
# 1001                        2.53                     5.55
# 1002                        1.58                     8.84
# 1003                        1.70                     9.35
# 1004                        1.98                    14.53
#
#       Acceso a TikTok (en hs)
# 0                        3.69
# 1                        4.06
# 2                        4.77
# 3                        4.19
# 4                        5.39
# ...                       ...
# 1000                     8.40
# 1001                    10.96
# 1002                    14.01
# 1003                     8.83
# 1004                     4.46
#
# [801 rows x 7 columns]

# %% [markdown]
# Para sacar duplicados

# %%
datos2 = datos1.drop_duplicates().reset_index(drop = True)

# %% [markdown]
# Para sacar nan

# %%
datos3 = datos.dropna().reset_index(drop= True)

# %%
datos3
# Out:
#         Fecha    Dirección IP  Actividad (en hs)  Acceso a Facebook (en hs)  \
# 0    16/09/20  242.99.117.120               3.36                       0.57
# 1    06/05/20    181174223110               4.28                       2.91
# 2    01/10/21   58.54.184.167               5.62                       2.60
# 3    01/03/17  135.79.184.226               5.83                       2.15
# 4    01/02/21    248.230.40.6               4.59                       1.79
# ..        ...             ...                ...                        ...
# 922  02/04/20   93.205.225.51               5.68                       1.95
# 923  07/02/19   43.55.114.100               4.62                       2.05
# 924  25/01/20  147.210.83.222               6.21                       1.98
# 925  03/07/17  117.69.141.168               4.69                       2.41
# 926  09/03/18   29.229.177.12               6.50                       1.62
#
#      Acceso a Instagram (en hs)  Acceso a Twitch (en hs)  \
# 0                          8.81                     1.95
# 1                          9.66                     3.45
# 2                          6.95                     1.94
# 3                          7.82                     2.03
# 4                         11.67                     1.46
# ..                          ...                      ...
# 922                        1.76                    10.00
# 923                        2.53                     5.55
# 924                        1.58                     8.84
# 925                        1.70                     9.35
# 926                        1.98                    14.53
#
#      Acceso a TikTok (en hs)
# 0                       3.69
# 1                       4.06
# 2                       4.77
# 3                       4.19
# 4                       5.39
# ..                       ...
# 922                     8.40
# 923                    10.96
# 924                    14.01
# 925                     8.83
# 926                     4.46
#
# [927 rows x 7 columns]

# %%
sns.pairplot(datos3)

# %%
scaler = StandardScaler()
datos_escalado = scaler.fit_transform(datos3[columnas])

# %%
def inercias_por_k(datos_escalado):
  inercias = {}
  for i in range(1,11):
      kmeans = KMeans(n_clusters = i, init="random", n_init=10, max_iter=300, random_state=123457)
      kmeans.fit(datos_escalado)
      inercias[i] = kmeans.inertia_
  return inercias

# %%
inercias = inercias_por_k(datos_escalado)

# %%
inercias
# Out:
# {1: 4635.0,
#  2: 2491.912812419104,
#  3: 1950.4360237301642,
#  4: 1450.5461028211307,
#  5: 1323.1640943299208,
#  6: 1194.077829068784,
#  7: 1075.2654901517117,
#  8: 995.1937038584014,
#  9: 950.0623382841189,
#  10: 880.0488679446084}

# %%
datos_inercias = pd.DataFrame(inercias.items(),columns=["k","inercia"] )

# %%
sns.pointplot(data = datos_inercias, x = "k", y ="inercia")
# Out:
# <AxesSubplot:xlabel='k', ylabel='inercia'>

# %%
k = 2
#agrupar
KMeans = KMeans(n_clusters=k, init = "random",n_init=10,max_iter=500,random_state=123457)
KMeans.fit(datos_escalado)
# Out:
# KMeans(init='random', max_iter=500, n_clusters=2, random_state=123457)

# %%
colores = ["red", "green"]
sns.scatterplot(x = datos_escalado[:,2], y= datos_escalado[:,0], hue = KMeans.labels_, palette = colores, alpha = 0.5)
sns.scatterplot(x = KMeans.cluster_centers_[:,2], y = KMeans.cluster_centers_[:, 0], zorder = 10, palette = colores, hue= [0,1], legend = False, marker = 6, s = 200)
# Out:
# <AxesSubplot:>

# %%
silhouette_avg = silhouette_score(datos_escalado, KMeans.labels_)
sample_silhouette_values = silhouette_samples(datos_escalado, KMeans.labels_)

def graficarSilhouette (k, labels, sample_silhouette_values, silhouette_avg):
  fig, ax1 = plt.subplots(1, 1)
  y_lower = 10
  for i in range(k):
      ith_cluster_silhouette_values = \
          sample_silhouette_values[labels == i]

      ith_cluster_silhouette_values.sort()

      size_cluster_i = ith_cluster_silhouette_values.shape[0]
      y_upper = y_lower + size_cluster_i

      color = cm.nipy_spectral(float(i) / k)
      ax1.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values, facecolor=color, edgecolor=color, alpha=0.7)
      ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
      y_lower = y_upper + 10

  ax1.set_title("Plot del silhouette de cada cluster")
  ax1.set_xlabel("Coeficiente de silhouette")
  ax1.set_ylabel("Etiqueta del cluster")
  ax1.axvline(x=silhouette_avg, color="red", linestyle="--")
  ax1.set_yticks([])

graficarSilhouette (k, KMeans.labels_, sample_silhouette_values, silhouette_avg)
